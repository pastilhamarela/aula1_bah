# %% [markdown]
# <a href="https://colab.research.google.com/github/pastilhamarela/aula1_bah/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# name of folder principal
from transformers import T5Tokenizer, T5ForConditionalGeneration

model_checkpoint = "stjiris/t5-portuguese-legal-summarization"
t5_model = T5ForConditionalGeneration.from_pretrained(model_checkpoint)
t5_tokenizer = T5Tokenizer.from_pretrained(model_checkpoint)
# Out:
# Summarized text:
# ...

# %% [markdown]
# # Inquérito

# %%
preprocess_text  = """
Inquérito Policial nº 123/2024

Delegacia de Polícia Civil do Estado de São Paulo

Local: São Paulo, SP

Data: 15 de abril de 2024

Natureza: Roubo a Banco

Investigador Responsável: Inspetor Marcos Silva

Relatório Preliminar:

Em conformidade com a solicitação da autoridade competente, deu-se início às investigações referentes ao roubo ocorrido na agência bancária do Banco Central, localizada na Avenida Paulista, nº 1000, São Paulo, SP, no dia 10 de abril de 2024, por volta das 10h da manhã.

Segundo relatos de testemunhas oculares e câmeras de segurança, um grupo de cinco indivíduos fortemente armados, utilizando máscaras e roupas escuras, invadiu a agência e anunciou o assalto. Os criminosos renderam clientes e funcionários, exigindo acesso ao cofre principal.

Durante a ação criminosa, os assaltantes utilizaram armas de fogo de alto calibre e explosivos para abrir o cofre, causando danos materiais significativos à estrutura do banco. Após subtrair uma quantia estimada em R$ 5.000.000,00 (cinco milhões de reais), os criminosos fugiram do local em dois veículos roubados, um sedan preto e uma van branca, que foram abandonados e incendiados em ruas próximas.

A equipe de investigação realizou buscas no perímetro do crime, coletando evidências como cápsulas de munição, fragmentos de explosivos, impressões digitais e amostras de DNA. Além disso, foram entrevistadas testemunhas e vítimas em busca de informações adicionais que pudessem auxiliar na identificação e captura dos suspeitos.

No entanto, até o momento, nenhum dos indivíduos envolvidos no roubo foi identificado ou capturado. As investigações estão em andamento, e novas diligências estão sendo planejadas para esclarecer os detalhes do crime e responsabilizar os culpados.

Com base nas informações obtidas até o momento, este inquérito permanece em aberto para investigações adicionais. Todas as provas e documentos pertinentes estão sendo devidamente catalogados e preservados para eventual apresentação em juízo.

São Paulo, 15 de abril de 2024.

Assinatura do Inspetor Marcos Silva
"""

# %%
t5_prepared_Text = "summarize: "+preprocess_text
#print ("original text preprocessed: \n", preprocess_text)

tokenized_text = t5_tokenizer.encode(t5_prepared_Text, return_tensors="pt")


# summmarize
summary_ids = t5_model.generate(tokenized_text,
                                    num_beams=4,
                                    no_repeat_ngram_size=2,
                                    min_length=100,
                                    max_length=500,
                                    early_stopping=True)

output = t5_tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print ("\n\nSummarized text: \n",output)
# Out:
# Summarized text:
# ...

# %%
from transformers import BertTokenizerFast, BertForQuestionAnswering, pipeline
model_name = "NchuNLP/Legal-Document-Question-Answering"
tokenizer = BertTokenizerFast.from_pretrained(model_name)
model = BertForQuestionAnswering.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00
Ocorrência - Ofício ao Diretor do Presídio 5752/2023 04/07/2023 18:08
Ocorrência - Ofício ao Promotor 5751/2023 04/07/2023 18:08
Ocorrência - Ofício ao Juiz 5750/2023 04/07/2023 18:08
Ocorrência - Termo Cientificação Direitos Constitucionais 5749/2023 04/07/2023 18:07
Ocorrência - Nota de Culpa 5748/2023 04/07/2023 18:06
Ocorrência - Informações sobre a Vida Pregressa 5747/2023 04/07/2023 18:05
Ocorrência - Portaria de Nomeação de Peritos 5746/2023 04/07/2023 18:02
Ocorrência - Auto de Apreensão 5745/2023 04/07/2023 18:01
Ocorrência - Corpo da Assentada - Adulto 5744/2023 04/07/2023 18:00
Ocorrência - Perícia em Indivíduo 5743/2023 04/07/2023 17:59
Ocorrência - Certidão 5742/2023 04/07/2023 17:58
Ocorrência - Documento Escaneado 5741/2023 04/07/2023 17:55

Destino: 1° Via:
Equipe
Atendente: FERNANDA FERNANDES
Chefe Plantão: CESAR MARTINS
Autor. Policial: DANIEL TRAMADOL
"""

# %%
# a) Get predictions
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)
QA_input = {
    'question': 'Indicar a data do crime',
    'context': context
}
res = nlp(QA_input)
res
# Out:
# {'score': 0.15579630434513092,
#  'start': 4280,
#  'end': 4290,
#  'answer': 'Ocorrência'}

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# model & tokenizer
model_name = "pierreguillou/t5-base-qa-squad-v1.1-portuguese"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.00k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/756k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
max_target_length=32
num_beams=1
early_stopping=True

# %%
question = "Qual a data registro?"
input_text  = 'question: ' + question + 'context: ' + context


inputs = tokenizer(input_text, return_tensors="pt")

# %%
inputs
# Out:
# {'input_ids': tensor([[  13,    6, 1329,  ..., 5846,   31,    1]]), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]])}

# %%
outputs = model.generate(inputs["input_ids"],
                             max_length=max_target_length,
                             num_beams=num_beams,
                             early_stopping=early_stopping
                            )
pred = tokenizer.decode(outputs[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)

#print('true answer |', label)
print('pred        |', pred)
# Out:
# pred        | 04/07/2023 às 17:06 horas

# %%
model_name = 'pierreguillou/bert-base-cased-squad-v1.1-portuguese'
nlp = pipeline("question-answering", model=model_name)

question = "Qual é a data de registro?"
result = nlp(question=question, context=context)

print(f"Answer: '{result['answer']}', score: {round(result['score'], 4)}, start: {result['start']}, end: {result['end']}")
# Out:
# Answer: '27/03/1976', score: 0.841, start: 1175, end: 1185

# %%
import re
match = re.search(r'Data Registro: (\d{2}/\d{2}/\d{4})', context)
if match:
    data_registro = match.group(1)
    print("Data Registro:", data_registro)
else:
    print("Data Registro não encontrada")
# Out:
# Data Registro: 04/07/2023
